# %%
# Load image im1.png and im2.png and display them side by side

import cv2
import matplotlib.pyplot as plt
import numpy as np

# Load the images
im1 = cv2.imread('im1.png')
im2 = cv2.imread('im2.png')

# Display the images
plt.subplot(1, 2, 1)    
plt.imshow(cv2.cvtColor(im1, cv2.COLOR_BGR2RGB))
plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(im2, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# Show the difference between the images
diff = cv2.absdiff(im1, im2)
#Convert to grayscale
diff = cv2.cvtColor(diff, cv2.COLOR_BGR2GRAY)
diff = np.
# Out:
# [ WARN:0@2083.504] global loadsave.cpp:848 imwrite_ Unsupported depth image for selected encoder is fallbacked to CV_8U.
# True

# %%
# Print max value of the difference image
print(diff.max())
# Out:
# 1.0
